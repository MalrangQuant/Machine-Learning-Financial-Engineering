# %% [markdown]
# # 영화 상세 페이지 리뷰 데이터 크롤링

# %%
import requests
from urllib import parse
from bs4 import BeautifulSoup

import random
import time

import pandas as pd

# %% [markdown]
# # HTML 코드 확인

# %%
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=80707&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20211015113922" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20211015113922" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20211015113922" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20211015113922" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="80707"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# ...

# %%
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																진짜 재밌다. 연속으로 미국 박스오피스 1위하고, 상당한 수익 벌어들인게 이해가 간다. 야릇한 농담에 진지빠는 선비님들 아니면 정말 재밌게 볼 수 있는 영화!
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(8196107, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>bmw(xpys****)</span>
# </a>
# </em>
# <em>2013.12.07 08:13</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','xpys****', '406Mu4NdlAwQEsA1Ouu1ASuShRlQmGIHjVe+oUQdf2Q=', '진짜 재밌다. 연속으로 미국 박스오피스 1위하고, 상당한 수익 벌어들인게 이해가 간다. 야릇한 농담에 진지빠는 선비님들 아니면 정말 재밌게 볼 수 있는 영화! ', '8196107', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# ...

# %%
review_text = lis[0].find('p').getText().strip()
review_text
# Out:
# '진짜 재밌다. 연속으로 미국 박스오피스 1위하고, 상당한 수익 벌어들인게 이해가 간다. 야릇한 농담에 진지빠는 선비님들 아니면 정말 재밌게 볼 수 있는 영화!'

# %%
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %% [markdown]
# # 첫 번째 페이지 크롤링

# %%
def get_data(url):
    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    
    for li in lis:
        score = li.find('em').getText()
        review_text = li.find('p').getText().strip()
        
        if review_text.startswith('관람객'):
            review_text = review_text[3:].strip()
        
        print(score, ':', review_text)
        print('---------------------------------------------')

# %%
get_data(test_url)
# Out:
# 10 : 진짜 재밌다. 연속으로 미국 박스오피스 1위하고, 상당한 수익 벌어들인게 이해가 간다. 야릇한 농담에 진지빠는 선비님들 아니면 정말 재밌게 볼 수 있는 영화!
# ---------------------------------------------
# 10 : 아 테드진짜귀여움ㅋㅋㅋ 그냥 한없이 웃고싶을때좋은영화임ㅋㅋ
# ---------------------------------------------
# 7 : 천박한 입버릇에서 모든 재미가 나온다. 브로맨스를 잘 살린 점은 좋았으나 처음부터 끝까지 너무 규칙적이다.
# ---------------------------------------------
# 10 : 미국 사회나 인물 잘 알면 더 웃김ㅋㅋㅋ 무근본 병맛유머의 코메디인데 진짜 추천함. 테드의 찰진 드립이 시도때도없이 빵빵 터진다. 감동도 더하면서, 끝나는 순간까지 웃음짓게하는 목적에 충실한 영화. 라이언과 테일러 ...
# ---------------------------------------------
# 10 : 테드랑 직장상사 ㅋㅋㅋㅋ
# ---------------------------------------------
# 10 : 배꼽터진다 근데 평점이 왜케 낮아 ?
# ---------------------------------------------
# 10 : 드립이 찰지네.  테드가 취직한 슈퍼 나도 가고싶네ㅋ
# ---------------------------------------------
# 10 : 이건 8090년대 미국정서랑 문화의 이해가 있다면 최고의 코미디
# ---------------------------------------------
# 10 : 내반지는 이자식아ㅋㅋㅋㅋ이 썬오브비칰ㅋㅋㅋ테드 좋음
# ---------------------------------------------
# 10 : 중간중간 깨알같은 조크와 질펀한 욕들,코미디영화에선 생각도 못한 액션씬등 정말 즐겁게봤다
# ...

# %% [markdown]
# # 전체 페이지 크롤링

# %%
base_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=80707&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={}"

# %%
random.uniform(0.2, 1.2)
# Out:
# 0.619511870331455

# %%
# 결과 저장 list
comment_list = []

for page in range(1, 164):
    url = base_url.format(page)
    res = requests.get(url)
    
    if res.status_code == 200:
        soup = BeautifulSoup(res.content, 'html.parser')
        
        score_result = soup.find('div', {'class': 'score_result'})
        lis = score_result.findAll('li')
        
        for li in lis:
            score = li.find('em').getText()
            comment = li.find('p').getText().strip()
            
            # 관람객 리뷰인 경우 리뷰 앞에 '관람객' 태그가 붙으므로 제거해준다
            if comment.startswith('관람객'):
                comment = comment[3:].strip()
            
            comment_list.append((url, score, comment))
            
        # 크롤링 시 너무 자주 접근하면 사이트가 접근 방지할 수 있으므로 딜레이 걸어줌
        interval = round(random.uniform(0.2, 1.2), 2)
        time.sleep(interval)
        
print("finish")
# Out:
# finish

# %%
df = pd.DataFrame(comment_list, columns=['link', 'score', 'review'])
df.head(20)
# Out:
#                                                  link score  \
# 0   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 1   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 2   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 3   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 4   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 5   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 6   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 7   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 8   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 9   https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 10  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 11  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 12  https://movie.naver.com/movie/bi/mi/pointWrite...     7
# 13  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 14  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# ...

# %%
# title의 괄호 부분에 영화 이름을 적어넣는다.
# 해당 크롤링 방식은 영화 이름을 크롤링해올 수 없기 때문에 수동으로 채워 넣어야 한다.
title = pd.DataFrame(['19곰 테드']*len(df), columns=['title'])
df = title.join(df)
df.head()
# Out:
#     title                                               link score  \
# 0  19곰 테드  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 1  19곰 테드  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 2  19곰 테드  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 3  19곰 테드  https://movie.naver.com/movie/bi/mi/pointWrite...    10
# 4  19곰 테드  https://movie.naver.com/movie/bi/mi/pointWrite...    10
#
#                                               review
# 0                             아 정말ㅋㅋㅋㅋㅋ 이런 유머 너무 좋아요
# 1            죤나게재밌다.어린시절의 순수함을 가지고 성인이 됀사람이라면 무조건 추천
# 2  진짜웃김ㅋㅋㅋ곰인형이 주인공이랑 싸울때 바지벗기고 회초리로 엉덩이 때리는부분 짱 웃...
# 3                    인간과 봉제곰의 격렬한 액션씬이 가장 인상에 남는 작품.
# 4                                            진짜ㅋㅋㅋㅋ굿

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1630 non-null   object
#  1   link    1630 non-null   object
#  2   score   1630 non-null   object
#  3   review  1630 non-null   object
# dtypes: object(4)
# memory usage: 51.1+ KB

# %%
df.to_csv('naver_movie_review_1106_Ted.csv', encoding='euckr', index=False)
